# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
superstore = pd.read_excel("./superstore.xlsx")

# %%
superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order ID            9994 non-null   object
#  1   Order Date          9994 non-null   datetime64[ns]
#  2   Ship Date           9994 non-null   datetime64[ns]
#  3   Ship Mode           9994 non-null   object
#  4   Customer ID         9994 non-null   object
#  5   Customer Name       9994 non-null   object
#  6   Segment             9994 non-null   object
#  7   Sales Rep           9994 non-null   object
#  8   Sales Team          9994 non-null   object
#  9   Sales Team Manager  9994 non-null   object
#  10  Location ID         9994 non-null   object
#  11  City                9994 non-null   object
#  12  State               9994 non-null   object
#  13  Postal Code         9994 non-null   int64
#  14  Region              9994 non-null   object
# ...

# %%
superstore.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment     Sales Rep Sales Team Sales Team Manager  \
# 0      Claire Gute   Consumer       Organic    Organic            Organic
# 1      Claire Gute   Consumer       Organic    Organic            Organic
# 2  Darrin Van Huff  Corporate  Steve Pepple      Bravo        Tracy Banks
# 3   Sean O'Donnell   Consumer       Organic    Organic            Organic
# 4   Sean O'Donnell   Consumer       Organic    Organic            Organic
#
#    ... Postal Code Region                                         Product ID  \
# ...

# %%
total_sales = superstore['Sales'].sum()

# %%
total_sales # total sales
# Out:
# 2297200.8603000003

# %%
superstore.tail()
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 9989  CA-2014-110422 2014-01-21 2014-01-23    Second Class    TB-21400
# 9990  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9993  CA-2017-119914 2017-05-04 2017-05-09    Second Class    CC-12220
#
#          Customer Name   Segment Sales Rep Sales Team Sales Team Manager  ...  \
# 9989  Tom Boeckenhauer  Consumer   Organic    Organic            Organic  ...
# 9990       Dave Brooks  Consumer   Organic    Organic            Organic  ...
# 9991       Dave Brooks  Consumer   Organic    Organic            Organic  ...
# 9992       Dave Brooks  Consumer   Organic    Organic            Organic  ...
# 9993      Chris Cortes  Consumer   Organic    Organic            Organic  ...
#
# ...

# %%
superstore.describe()
# Out:
#                           Order Date                      Ship Date  \
# count                           9994                           9994
# mean   2016-04-30 00:07:12.259355648  2016-05-03 23:06:58.571142912
# min              2014-01-03 00:00:00            2014-01-07 00:00:00
# 25%              2015-05-23 00:00:00            2015-05-27 00:00:00
# 50%              2016-06-26 00:00:00            2016-06-29 00:00:00
# 75%              2017-05-14 00:00:00            2017-05-18 00:00:00
# max              2017-12-30 00:00:00            2018-01-05 00:00:00
# std                              NaN                            NaN
#
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# ...

# %%
total_profit = superstore["Profit"].sum() # total_profit
total_profit
# Out:
# 286397.0216999999

# %%
superstore["Total Revenue"] = superstore["Sales"]*superstore["Quantity"]

# %%
superstore.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment     Sales Rep Sales Team Sales Team Manager  \
# 0      Claire Gute   Consumer       Organic    Organic            Organic
# 1      Claire Gute   Consumer       Organic    Organic            Organic
# 2  Darrin Van Huff  Corporate  Steve Pepple      Bravo        Tracy Banks
# 3   Sean O'Donnell   Consumer       Organic    Organic            Organic
# 4   Sean O'Donnell   Consumer       Organic    Organic            Organic
#
#    ... Region                                         Product ID  \
# ...

# %%
total_revenue = superstore["Total Revenue"].sum()
total_revenue
# Out:
# 11488062.0719

# %%
profit_margin = (total_profit/ total_revenue)*100
profit_margin
# Out:
# 2.492996816238763

# %%
best_performing_quantity_segment = superstore.groupby('Segment')['Quantity'].sum()
best_performing_quantity_segment
# Out:
# Segment
# Consumer       19521
# Corporate      11608
# Home Office     6744
# Name: Quantity, dtype: int64

# %%
best_perfoming_sales_segment = superstore.groupby("Segment")["Sales"].sum()
best_perfoming_sales_segment
# Out:
# Segment
# Consumer       1.161401e+06
# Corporate      7.061464e+05
# Home Office    4.296531e+05
# Name: Sales, dtype: float64

# %%
profit_segment = superstore.groupby("Segment")["Profit"].sum()
profit_segment
# Out:
# Segment
# Consumer       134119.2092
# Corporate       91979.1340
# Home Office     60298.6785
# Name: Profit, dtype: float64

# %%
superstore["Segment"].nunique()
# Out:
# 3

# %%
categories_quantity = superstore.groupby("Category")["Quantity"].sum()
categories_quantity
# Out:
# Category
# Furniture           8028
# Office Supplies    22906
# Technology          6939
# Name: Quantity, dtype: int64

# %%
categories_sales  = superstore.groupby("Category")["Sales"].sum()
categories_sales
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
categories_profit  = superstore.groupby("Category")["Profit"].sum()
categories_profit
# Out:
# Category
# Furniture           18451.2728
# Office Supplies    122490.8008
# Technology         145454.9481
# Name: Profit, dtype: float64

# %%
subcategories_profit  =superstore.groupby("Sub-Category")["Profit"].sum().sort_values(ascending = False).to_frame()
subcategories_profit
# Out:
#                   Profit
# Sub-Category
# Copiers       55617.8249
# Phones        44515.7306
# Accessories   41936.6357
# Paper         34053.5693
# Binders       30221.7633
# Chairs        26590.1663
# Storage       21278.8264
# Appliances    18138.0054
# Furnishings   13059.1436
# Envelopes      6964.1767
# Art            6527.7870
# Labels         5546.2540
# Machines       3384.7569
# Fasteners       949.5182
# Supplies      -1189.0995
# Bookcases     -3472.5560
# Tables       -17725.4811

# %%
subcategories_profit.head(10)
# Out:
#                   Profit
# Sub-Category
# Copiers       55617.8249
# Phones        44515.7306
# Accessories   41936.6357
# Paper         34053.5693
# Binders       30221.7633
# Chairs        26590.1663
# Storage       21278.8264
# Appliances    18138.0054
# Furnishings   13059.1436
# Envelopes      6964.1767

# %%
product_perfomance = superstore.groupby('Product Name')['Quantity'].sum().sort_values(ascending = False).to_frame()
product_perfomance
# Out:
#                                                     Quantity
# Product Name
# Staples                                                  215
# Staple envelope                                          170
# Easy-staple paper                                        150
# Staples in misc. colors                                   86
# KI Adjustable-Height Table                                74
# ...                                                      ...
# Global Enterprise Series Seating Low-Back Swive...         1
# Xerox 20                                                   1
# Penpower WorldCard Pro Card Scanner                        1
# Bush Saratoga Collection 5-Shelf Bookcase, Hano...         1
# Boston 1900 Electric Pencil Sharpener                      1
#
# [1850 rows x 1 columns]

# %%
product_perfomance.head(10)
# Out:
#                                                     Quantity
# Product Name
# Staples                                                  215
# Staple envelope                                          170
# Easy-staple paper                                        150
# Staples in misc. colors                                   86
# KI Adjustable-Height Table                                74
# Avery Non-Stick Binders                                   71
# Storex Dura Pro Binders                                   71
# GBC Premium Transparent Covers with Diagonal Li...        67
# Situations Contoured Folding Chairs, 4/Set                64
# Staple-based wall hangings                                62

# %%
product_sales = superstore.groupby("Product Name")["Sales"].sum().sort_values(ascending=False).to_frame()
product_sales
# Out:
#                                                         Sales
# Product Name
# Canon imageCLASS 2200 Advanced Copier               61599.824
# Fellowes PB500 Electric Punch Plastic Comb Bind...  27453.384
# Cisco TelePresence System EX90 Videoconferencin...  22638.480
# HON 5400 Series Task Chairs for Big and Tall        21870.576
# GBC DocuBind TL300 Electric Binding System          19823.479
# ...                                                       ...
# Avery Hi-Liter Pen Style Six-Color Fluorescent Set      7.700
# Grip Seal Envelopes                                     7.072
# Xerox 20                                                6.480
# Avery 5                                                 5.760
# Eureka Disposable Bags for Sanitaire Vibra Groo...      1.624
#
# [1850 rows x 1 columns]

# %%
product_sales.head(10)
# Out:
#                                                         Sales
# Product Name
# Canon imageCLASS 2200 Advanced Copier               61599.824
# Fellowes PB500 Electric Punch Plastic Comb Bind...  27453.384
# Cisco TelePresence System EX90 Videoconferencin...  22638.480
# HON 5400 Series Task Chairs for Big and Tall        21870.576
# GBC DocuBind TL300 Electric Binding System          19823.479
# GBC Ibimaster 500 Manual ProClick Binding System    19024.500
# Hewlett Packard LaserJet 3310 Copier                18839.686
# HP Designjet T520 Inkjet Large Format Printer -...  18374.895
# GBC DocuBind P400 Electric Binding System           17965.068
# High Speed Automatic Electric Letter Opener         17030.312

# %%
product_profit = superstore.groupby("Product Name")["Profit"].sum().sort_values(ascending=False).to_frame()
product_profit
# Out:
#                                                         Profit
# Product Name
# Canon imageCLASS 2200 Advanced Copier               25199.9280
# Fellowes PB500 Electric Punch Plastic Comb Bind...   7753.0390
# Hewlett Packard LaserJet 3310 Copier                 6983.8836
# Canon PC1060 Personal Laser Copier                   4570.9347
# HP Designjet T520 Inkjet Large Format Printer -...   4094.9766
# ...                                                        ...
# Bush Advantage Collection Racetrack Conference ...  -1934.3976
# Chromcraft Bull-Nose Wood Oval Conference Table...  -2876.1156
# Cubify CubeX 3D Printer Triple Head Print           -3839.9904
# Lexmark MX611dhe Monochrome Laser Printer           -4589.9730
# Cubify CubeX 3D Printer Double Head Print           -8879.9704
#
# [1850 rows x 1 columns]

# %%
product_profit.head(10)
# Out:
#                                                         Profit
# Product Name
# Canon imageCLASS 2200 Advanced Copier               25199.9280
# Fellowes PB500 Electric Punch Plastic Comb Bind...   7753.0390
# Hewlett Packard LaserJet 3310 Copier                 6983.8836
# Canon PC1060 Personal Laser Copier                   4570.9347
# HP Designjet T520 Inkjet Large Format Printer -...   4094.9766
# Ativa V4110MDD Micro-Cut Shredder                    3772.9461
# 3D Systems Cube Printer, 2nd Generation, Magenta     3717.9714
# Plantronics Savi W720 Multi-Device Wireless Hea...   3696.2820
# Ibico EPK-21 Electric Binding System                 3345.2823
# Zebra ZM400 Thermal Label Printer                    3343.5360
